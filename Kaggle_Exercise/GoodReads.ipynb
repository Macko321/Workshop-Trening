# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv("books.csv", error_bad_lines=False, index_col='bookID')

# %%
data=df_1.drop(columns=['isbn', 'isbn13','Unnamed: 12','Unnamed: 13','Unnamed: 14'])

# %%
data
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                   ...
# 40138                                  Bone In The Throat
# 40139                                         Gone Bamboo
# 40143   The Family That Couldn't Sleep: A Medical Mystery
# 40145        Dear Genius: The Letters of Ursula Nordstrom
# 40146   Dear Genius...": A Memoir of My Life with Trum...
#
#                                                   authors average_rating  \
# bookID
# 1                              J.K. Rowling/Mary GrandPré           4.57
# 2                              J.K. Rowling/Mary GrandPré           4.49
# ...

# %%
data.dtypes
# Out:
# title                 object
# authors               object
# average_rating        object
# language_code         object
# num_pages             object
# ratings_count         object
# text_reviews_count    object
# publication_date      object
# publisher             object
# dtype: object

# %%
df_1.index
# Out:
# Int64Index([    1,     2,     4,     5,     8,     9,    10,    12,    13,
#                14,
#             ...
#             40106, 40127, 40128, 40130, 40132, 40138, 40139, 40143, 40145,
#             40146],
#            dtype='int64', name='bookID', length=8472)

# %%
#Print column name
for col in data.columns: 
    print(col)
# Out:
# title
# authors
# average_rating
# language_code
# num_pages
# ratings_count
# text_reviews_count
# publication_date
# publisher

# %%
data.head(20)
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 9       Unauthorized Harry Potter Book Seven News: "Ha...
# 10           Harry Potter Collection (Harry Potter  #1-6)
# 12      The Ultimate Hitchhiker's Guide: Five Complete...
# 13      The Ultimate Hitchhiker's Guide to the Galaxy ...
# 14      The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 16      The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 18      The Ultimate Hitchhiker's Guide (Hitchhiker's ...
# 21                   A Short History of Nearly Everything
# 22                            Bill Bryson's African Diary
# 23      Bryson's Dictionary of Troublesome Words: A Wr...
# ...

# %%
df_1.tail(20)
# Out:
#                                                     title  \
# bookID
# 40051                                             Evening
# 40053   Three Genres: Writing Fiction/Literary Nonfict...
# 40054                                        The Tiny One
# 40067                                       Thunderstruck
# 40070   The Naked Consumer: How Our Private Lives Beco...
# 40076   Artful Paper Dolls: New Ways to Play with a Tr...
# 40081     The Meanest Doll in the World (Doll People  #2)
# 40090                         Sacred Games (Sacred Games)
# 40100   Riding the Bus with My Sister: A True Life Jou...
# 40102       Blink: The Power of Thinking Without Thinking
# 40106                                     Beatrice's Goat
# 40127                                    Leonardo's Swans
# 40128                  The Notebooks of Leonardo da Vinci
# 40130   Leonardo da Vinci: Obra pictorica completa y o...
# 40132   Leonardo on Painting: An Anthology of Writings...
# ...

# %%
#plt.figure(figsize=(10,8))



#sns.barplot(x=data['num_pages'],y=data['text_reviews_count'])

# %%
#More visualization tools

# %%
sns.set_context(context='poster')
plt.figure(figsize=(20,15))
books = data['title'].value_counts(dropna=True)[:20]
sns.barplot(x = books, y = books.index, palette = 'deep')

plt.show()

# %%
sns.set_context(context='talk')
plt.figure(figsize=(20,15))
books = df_1['title'].value_counts()[:20]
review = df_1.text_reviews_count[:20]
sns.barplot(x = review, y = review.index, palette = 'deep')
plt.show()

# %%
# sns.set_context(context='poster')
# plt.figure(figsize=(40,50))
# authors = df_1['authors'].value_counts()[:30]

# sns.barplot(x = authors, y = authors.index, palette = 'deep')

# plt.title("Authors with most books")
# plt.xlabel("Number of books")
# plt.ylabel("Authors")
# plt.show()

# %%
data.dtypes
# Out:
# title                 object
# authors               object
# average_rating        object
# language_code         object
# num_pages             object
# ratings_count         object
# text_reviews_count    object
# publication_date      object
# publisher             object
# dtype: object

# %%
data_2=df_1.drop(columns=['isbn','isbn13','language_code'])

# %%
data_2.dtypes
# Out:
# title                 object
# authors               object
# average_rating        object
# num_pages             object
# ratings_count         object
# text_reviews_count    object
# publication_date      object
# publisher             object
# Unnamed: 12           object
# Unnamed: 13           object
# Unnamed: 14           object
# dtype: object
